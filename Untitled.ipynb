# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('data_final_2.csv')
#schema = pd.read_csv('survey_results_schema.csv')
df.head(1)
# Out:
#    Unnamed: 0  ConvertedComp  WorkWeekHrs  CodeRevHrs   Age  \
# 0           2         8820.0         40.0    4.868207  28.0
#
#    MainBranch_I am not primarily a developer, but I write code sometimes as part of my work  \
# 0                                                  1
#
#    Hobbyist_Yes  \
# 0             1
#
#    OpenSource_OSS is, on average, of LOWER quality than proprietary / closed source software  \
# 0                                                  0
#
#    OpenSource_The quality of OSS and closed source software is about the same  \
# 0                                                  1
#
#    Employment_Employed part-time  ...  \
# 0                              0  ...
#
#    WorkLoc_Other place, such as a coworking space or cafe  \
# 0                                                  0
#
#    UnitTests_No, but I think we should  \
# 0                                    1
#
#    UnitTests_Yes, it's not part of our process but the developers do it on their own  \
# 0                                                  0
#
#    UnitTests_Yes, it's part of our process  \
# 0                                        0
#
#    Gender_Man;Non-binary, genderqueer, or gender non-conforming  \
# 0                                                  0
#
#    Gender_Non-binary, genderqueer, or gender non-conforming  Gender_Woman  \
# 0                                                  0                    0
#
#    Gender_Woman;Man  \
# 0                 0
#
#    Gender_Woman;Man;Non-binary, genderqueer, or gender non-conforming  \
# 0                                                  0
#
#    Gender_Woman;Non-binary, genderqueer, or gender non-conforming
# 0                                                  0
#
# [1 rows x 10019 columns]

# %%
y = df['ConvertedComp']

# %%
x = df.drop(columns=['ConvertedComp'])
